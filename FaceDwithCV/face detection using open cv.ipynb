# %%
# !pip install --upgrade mediapipe


# !pip install matplotlib
import cv2
import mediapipe as mp

# Initialize MediaPipe Face Detection
mp_face = mp.solutions.face_detection
face_detection = mp_face.FaceDetection()

# Initialize MediaPipe Face Mesh
mp_face_mesh = mp.solutions.face_mesh
face_mesh = mp_face_mesh.FaceMesh()

# Initialize MediaPipe Drawing Utils
mp_drawing = mp.solutions.drawing_utils

# Initialize OpenCV
cap = cv2.VideoCapture(0)

while cap.isOpened():
    # Read frame from webcam
    ret, frame = cap.read()
    if not ret:
        break

    # Convert the BGR image to RGB
    rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    # Detect faces in the frame
    face_results = face_detection.process(rgb_frame)

    # Check if faces are detected
    if face_results.detections:
        for detection in face_results.detections:
            bboxC = detection.location_data.relative_bounding_box
            ih, iw, _ = frame.shape
            bbox = int(bboxC.xmin * iw), int(bboxC.ymin * ih), \
                   int(bboxC.width * iw), int(bboxC.height * ih)

            # Draw bounding box around the face
            cv2.rectangle(frame, bbox, (0, 255, 0), 2)

            # Detect face landmarks
            #landmarks = face_mesh.process(rgb_frame)
            #if landmarks.multi_face_landmarks:
                #for face_landmarks in landmarks.multi_face_landmarks:
                    # Draw face landmarks
                    #mp_drawing.draw_landmarks(frame, face_landmarks, mp_face_mesh.FACEMESH_TESSELATION)
                    
    # Display the frame
    cv2.imshow('Emotion Recognition', frame)

    # Break the loop if 'q' key is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the webcam and close all windows
cap.release()
cv2.destroyAllWindows()
# Out:
# Requirement already satisfied: mediapipe in c:\users\pabba\anaconda3\envs\abbas\lib\site-packages (0.10.9)
# Collecting mediapipe
#   Downloading mediapipe-0.10.10-cp311-cp311-win_amd64.whl.metadata (9.8 kB)
# Requirement already satisfied: absl-py in c:\users\pabba\appdata\roaming\python\python311\site-packages (from mediapipe) (2.0.0)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\pabba\anaconda3\envs\abbas\lib\site-packages (from mediapipe) (23.1.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\pabba\anaconda3\envs\abbas\lib\site-packages (from mediapipe) (23.5.26)
# Collecting jax (from mediapipe)
#   Downloading jax-0.4.25-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: matplotlib in c:\users\pabba\anaconda3\envs\abbas\lib\site-packages (from mediapipe) (3.8.3)
# Requirement already satisfied: numpy in c:\users\pabba\anaconda3\envs\abbas\lib\site-packages (from mediapipe) (1.24.3)
# Requirement already satisfied: opencv-contrib-python in c:\users\pabba\appdata\roaming\python\python311\site-packages (from mediapipe) (4.8.1.78)
# Requirement already satisfied: protobuf<4,>=3.11 in c:\users\pabba\anaconda3\envs\abbas\lib\site-packages (from mediapipe) (3.20.3)
# Requirement already satisfied: sounddevice>=0.4.4 in c:\users\pabba\appdata\roaming\python\python311\site-packages (from mediapipe) (0.4.6)
# Requirement already satisfied: CFFI>=1.0 in c:\users\pabba\anaconda3\envs\abbas\lib\site-packages (from sounddevice>=0.4.4->mediapipe) (1.16.0)
# Requirement already satisfied: ml-dtypes>=0.2.0 in c:\users\pabba\anaconda3\envs\abbas\lib\site-packages (from jax->mediapipe) (0.2.0)
# Requirement already satisfied: opt-einsum in c:\users\pabba\anaconda3\envs\abbas\lib\site-packages (from jax->mediapipe) (3.3.0)
# Requirement already satisfied: scipy>=1.9 in c:\users\pabba\anaconda3\envs\abbas\lib\site-packages (from jax->mediapipe) (1.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\pabba\anaconda3\envs\abbas\lib\site-packages (from matplotlib->mediapipe) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\pabba\anaconda3\envs\abbas\lib\site-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\pabba\anaconda3\envs\abbas\lib\site-packages (from matplotlib->mediapipe) (4.48.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\pabba\anaconda3\envs\abbas\lib\site-packages (from matplotlib->mediapipe) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\pabba\appdata\roaming\python\python311\site-packages (from matplotlib->mediapipe) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\pabba\anaconda3\envs\abbas\lib\site-packages (from matplotlib->mediapipe) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\pabba\anaconda3\envs\abbas\lib\site-packages (from matplotlib->mediapipe) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\pabba\appdata\roaming\python\python311\site-packages (from matplotlib->mediapipe) (2.8.2)
# Requirement already satisfied: pycparser in c:\users\pabba\anaconda3\envs\abbas\lib\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.21)
# Requirement already satisfied: six>=1.5 in c:\users\pabba\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.16.0)
# Downloading mediapipe-0.10.10-cp311-cp311-win_amd64.whl (50.7 MB)
#    ---------------------------------------- 0.0/50.7 MB ? eta -:--:--
#    ---------------------------------------- 0.3/50.7 MB 7.7 MB/s eta 0:00:07
#    ---------------------------------------- 0.6/50.7 MB 8.8 MB/s eta 0:00:06
#     --------------------------------------- 1.0/50.7 MB 9.0 MB/s eta 0:00:06
#    - -------------------------------------- 1.4/50.7 MB 8.9 MB/s eta 0:00:06
#    - -------------------------------------- 1.8/50.7 MB 9.4 MB/s eta 0:00:06
#    - -------------------------------------- 2.4/50.7 MB 10.0 MB/s eta 0:00:05
#    -- ------------------------------------- 2.8/50.7 MB 10.0 MB/s eta 0:00:05
#    -- ------------------------------------- 3.7/50.7 MB 11.6 MB/s eta 0:00:05
#    --- ------------------------------------ 4.5/50.7 MB 12.5 MB/s eta 0:00:04
#    --- ------------------------------------ 5.0/50.7 MB 12.6 MB/s eta 0:00:04
#    ---- ----------------------------------- 5.9/50.7 MB 13.4 MB/s eta 0:00:04
#    ----- ---------------------------------- 6.9/50.7 MB 14.2 MB/s eta 0:00:04
#    ------ --------------------------------- 8.1/50.7 MB 15.6 MB/s eta 0:00:03
#    ------- -------------------------------- 9.2/50.7 MB 16.3 MB/s eta 0:00:03
#    ------- -------------------------------- 9.6/50.7 MB 15.7 MB/s eta 0:00:03
#    ------- -------------------------------- 9.9/50.7 MB 15.1 MB/s eta 0:00:03
#    -------- ------------------------------- 10.5/50.7 MB 15.6 MB/s eta 0:00:03
#    -------- ------------------------------- 11.1/50.7 MB 16.0 MB/s eta 0:00:03
#    -------- ------------------------------- 11.3/50.7 MB 16.0 MB/s eta 0:00:03
#    --------- ------------------------------ 11.7/50.7 MB 15.6 MB/s eta 0:00:03
#    --------- ------------------------------ 11.9/50.7 MB 14.9 MB/s eta 0:00:03
#    --------- ------------------------------ 12.1/50.7 MB 14.9 MB/s eta 0:00:03
#    --------- ------------------------------ 12.3/50.7 MB 14.2 MB/s eta 0:00:03
#    --------- ------------------------------ 12.5/50.7 MB 13.6 MB/s eta 0:00:03
#    ---------- ----------------------------- 12.9/50.7 MB 13.4 MB/s eta 0:00:03
#    ---------- ----------------------------- 13.1/50.7 MB 13.1 MB/s eta 0:00:03
#    ---------- ----------------------------- 13.3/50.7 MB 12.8 MB/s eta 0:00:03
#    ---------- ----------------------------- 13.5/50.7 MB 12.1 MB/s eta 0:00:04
#    ---------- ----------------------------- 13.7/50.7 MB 11.7 MB/s eta 0:00:04
#    ----------- ---------------------------- 13.9/50.7 MB 11.1 MB/s eta 0:00:04
#    ----------- ---------------------------- 14.1/50.7 MB 10.9 MB/s eta 0:00:04
#    ----------- ---------------------------- 14.5/50.7 MB 10.6 MB/s eta 0:00:04
#    ----------- ---------------------------- 15.1/50.7 MB 10.6 MB/s eta 0:00:04
#    ------------ --------------------------- 15.6/50.7 MB 10.6 MB/s eta 0:00:04
#    ------------ --------------------------- 16.1/50.7 MB 10.2 MB/s eta 0:00:04
#    ------------- -------------------------- 16.9/50.7 MB 10.1 MB/s eta 0:00:04
#    ------------- -------------------------- 17.6/50.7 MB 9.9 MB/s eta 0:00:04
#    -------------- ------------------------- 18.4/50.7 MB 9.8 MB/s eta 0:00:04
#    -------------- ------------------------- 18.8/50.7 MB 9.5 MB/s eta 0:00:04
#    --------------- ------------------------ 19.3/50.7 MB 9.4 MB/s eta 0:00:04
#    --------------- ------------------------ 20.0/50.7 MB 9.8 MB/s eta 0:00:04
#    ---------------- -----------------------
MB 8.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 43.5/50.7 MB 8.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 43.9/50.7 MB 8.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 44.4/50.7 MB 8.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 44.7/50.7 MB 8.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 45.0/50.7 MB 8.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 45.5/50.7 MB 8.4 MB/s eta 0:00:01
#    ------------------------------------ --- 45.9/50.7 MB 8.4 MB/s eta 0:00:01
#    ------------------------------------ --- 46.2/50.7 MB 8.3 MB/s eta 0:00:01
#    ------------------------------------ --- 46.4/50.7 MB 8.1 MB/s eta 0:00:01
#    ------------------------------------ --- 46.6/50.7 MB 8.0 MB/s eta 0:00:01
#    ------------------------------------ --- 46.7/50.7 MB 7.8 MB/s eta 0:00:01
#    ------------------------------------- -- 47.0/50.7 MB 7.6 MB/s eta 0:00:01
#    ------------------------------------- -- 47.0/50.7 MB 7.5 MB/s eta 0:00:01
#    ------------------------------------- -- 47.0/50.7 MB 7.5 MB/s eta 0:00:01
#    ------------------------------------- -- 47.0/50.7 MB 7.5 MB/s eta 0:00:01
#    ------------------------------------- -- 47.0/50.7 MB 7.5 MB/s eta 0:00:01
#    ------------------------------------- -- 47.0/50.7 MB 7.5 MB/s eta 0:00:01
#    ------------------------------------- -- 47.0/50.7 MB 7.5 MB/s eta 0:00:01
#    ------------------------------------- -- 47.1/50.7 MB 6.4 MB/s eta 0:00:01
#    ------------------------------------- -- 47.1/50.7 MB 6.4 MB/s eta 0:00:01
#    ------------------------------------- -- 47.1/50.7 MB 6.4 MB/s eta 0:00:01
#    ------------------------------------- -- 47.1/50.7 MB 6.4 MB/s eta 0:00:01
#    ------------------------------------- -- 47.1/50.7 MB 6.4 MB/s eta 0:00:01
#    ------------------------------------- -- 47.1/50.7 MB 6.4 MB/s eta 0:00:01
#    ------------------------------------- -- 47.1/50.7 MB 5.5 MB/s eta 0:00:01
#    ------------------------------------- -- 47.2/50.7 MB 5.4 MB/s eta 0:00:01
#    ------------------------------------- -- 47.3/50.7 MB 5.3 MB/s eta 0:00:01
#    ------------------------------------- -- 47.5/50.7 MB 5.2 MB/s eta 0:00:01
#    ------------------------------------- -- 47.5/50.7 MB 5.2 MB/s eta 0:00:01
#    ------------------------------------- -- 47.5/50.7 MB 5.2 MB/s eta 0:00:01
#    ------------------------------------- -- 47.5/50.7 MB 5.2 MB/s eta 0:00:01
#    ------------------------------------- -- 47.6/50.7 MB 4.7 MB/s eta 0:00:01
#    ------------------------------------- -- 47.7/50.7 MB 4.7 MB/s eta 0:00:01
#    ------------------------------------- -- 47.7/50.7 MB 4.7 MB/s eta 0:00:01
#    ------------------------------------- -- 47.7/50.7 MB 4.5 MB/s eta 0:00:01
#    ------------------------------------- -- 47.7/50.7 MB 4.5 MB/s eta 0:00:01
#    ------------------------------------- -- 47.7/50.7 MB 4.5 MB/s eta 0:00:01
#    ------------------------------------- -- 47.7/50.7 MB 4.5 MB/s eta 0:00:01
#    ------------------------------------- -- 47.7/50.7 MB 4.5 MB/s eta 0:00:01
#    ------------------------------------- -- 47.7/50.7 MB 4.5 MB/s eta 0:00:01
#    ------------------------------------- -- 47.7/50.7 MB 4.5 MB/s eta 0:00:01
#    ------------------------------------- -- 47.7/50.7 MB 4.5 MB/s eta 0:00:01
#    ------------------------------------- -- 47.7/50.7 MB 4.5 MB/s eta 0:00:01
#    ------------------------------------- -- 47.7/50.7 MB 3.9 MB/s eta 0:00:01
#    ------------------------------------- -- 47.7/50.7 MB 3.9 MB/s eta 0:00:01
#    ------------------------------------- -- 47.7/50.7 MB 3.9 MB/s eta 0:00:01
#    ------------------------------------- -- 47.7/50.7 MB 3.9 MB/s eta 0:00:01
#    ------------------------------------- -- 47.7/50.7 MB 3.9 MB/s eta 0:00:01
#    ------------------------------------- -- 47.7/50.7 MB 3.9 MB/s eta 0:00:01
#    ------------------------------------- -- 47.7/50.7 MB 3.9 MB/s eta 0:00:01
#    ------------------------------------- -- 47.7/50.7 MB 3.9 MB/s eta 0:00:01
#    ------------------------------------- -- 47.7/50.7 MB 3.9 MB/s eta 0:00:01
#    ------------------------------------- -- 47.7/50.7 MB 3.9 MB/s eta 0:00:01
#    ------------------------------------- -- 47.7/50.7 MB 3.3 MB/s eta 0:00:01
#    ------------------------------------- -- 47.7/50.7 MB 3.3 MB/s eta 0:00:01
#    ------------------------------------- -- 47.7/50.7 MB 3.3 MB/s eta 0:00:01
#    ------------------------------------- -- 47.7/50.7 MB 3.3 MB/s eta 0:00:01
#    ------------------------------------- -- 47.7/50.7 MB 3.3 MB/s eta 0:00:01
#    ------------------------------------- -- 47.7/50.7 MB 3.3 MB/s eta 0:00:01
#    ------------------------------------- -- 47.7/50.7 MB 3.3 MB/s eta 0:00:01
#    ------------------------------------- -- 47.7/50.7 MB 3.3 MB/s eta 0:00:01
#    ------------------------------------- -- 47.7/50.7 MB 3.3 MB/s eta 0:00:01
#    ------------------------------------- -- 47.7/50.7 MB 3.3 MB/s eta 0:00:01
#    ------------------------------------- -- 47.7/50.7 MB 3.3 MB/s eta 0:00:01
#    ------------------------------------- -- 47.7/50.7 MB 2.9 MB/s eta 0:00:02
#    ------------------------------------- -- 47.7/50.7 MB 2.9 MB/s eta 0:00:02
#    ------------------------------------- -- 47.7/50.7 MB 2.9 MB/s eta 0:00:02
#    ------------------------------------- -- 47.7/50.7 MB 2.9 MB/s eta 0:00:02
#    ------------------------------------- -- 47.7/50.7 MB 2.9 MB/s eta 0:00:02
#    ------------------------------------- -- 47.7/50.7 MB 2.9 MB/s eta 0:00:02
#    ------------------------------------- -- 47.7/50.7 MB 2.9 MB/s eta 0:00:02
#    ------------------------------------- -- 47.7/50.7 MB 2.9 MB/s eta 0:00:02
#    ------------------------------------- -- 47.7/50.7 MB 2.9 MB/s eta 0:00:02
#    ------------------------------------- -- 47.7/50.7 MB 2.9 MB/s eta 0:00:02
#    ------------------------------------- -- 47.7/50.7 MB 2.9 MB/s eta 0:00:02
#    ------------------------------------- -- 47.7/50.7 MB 2.9 MB/s eta 0:00:02
#    ------------------------------------- -- 47.8/50.7 MB 2.5 MB/s eta 0:00:02
#    ------------------------------------- -- 47.9/50.7 MB 2.5 MB/s eta 0:00:02
#    ------------------------------------- -- 48.1/50.7 MB 2.5 MB/s eta 0:00:02
#    -------------------------------------- - 48.4/50.7 MB 2.5 MB/s eta 0:00:01
#    -------------------------------------- - 48.7/50.7 MB 2.5 MB/s eta 0:00:01
#    -------------------------------------- - 49.0/50.7 MB 2.5 MB/s eta 0:00:01
#    -------------------------------------- - 49.4/50.7 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  49.9/50.7 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  50.4/50.7 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  50.7/50.7 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------  50.7/50.7 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------  50.7/50.7 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------- 50.7/50.7 MB 2.4 MB/s eta 0:00:00
# Downloading jax-0.4.25-py3-none-any.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    -------------- ------------------------- 0.6/1.8 MB 20.5 MB/s eta 0:00:01
#    ------------------------- -------------- 1.2/1.8 MB 15.0 MB/s eta 0:00:01
#    ------------------------------------ --- 1.6/1.8 MB 14.9 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 12.8 MB/s eta 0:00:00
# Installing collected packages: jax, mediapipe
#   Attempting uninstall: mediapipe
#     Found existing installation: mediapipe 0.10.9
#     Uninstalling mediapipe-0.10.9:
#       Successfully uninstalled mediapipe-0.10.9
# Successfully installed jax-0.4.25 mediapipe-0.10.10
# Requirement already satisfied: matplotlib in c:\users\pabba\anaconda3\envs\abbas\lib\site-packages (3.8.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\pabba\anaconda3\envs\abbas\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\pabba\anaconda3\envs\abbas\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\pabba\anaconda3\envs\abbas\lib\site-packages (from matplotlib) (4.48.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\pabba\anaconda3\envs\abbas\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\pabba\anaconda3\envs\abbas\lib\site-packages (from matplotlib) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\pabba\appdata\roaming\python\python311\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\pabba\anaconda3\envs\abbas\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\pabba\anaconda3\envs\abbas\lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\pabba\appdata\roaming\python\python311\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\pabba\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# WARNING:tensorflow:From C:\Users\pabba\anaconda3\envs\abbas\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
